# %%
import numpy as np
import pandas as pd

# %%
dict1= {
    "name": ['Pardeep','Sachin','Akeel'],
    "Marks": [45,34,46],
    "City" : ['abc', 'def','xyz']
}
print(dict1)
# Out:
# {'name': ['Pardeep', 'Sachin', 'Akeel'], 'Marks': [45, 34, 46], 'City': ['abc', 'def', 'xyz']}

# %%
df= pd.DataFrame(dict1)
print(df)
# Out:
#       name  Marks City
# 0  Pardeep     45  abc
# 1   Sachin     34  def
# 2    Akeel     46  xyz

# %%
df.to_csv('lpu.csv')
df
# Out:
#       name  Marks City
# 0  Pardeep     45  abc
# 1   Sachin     34  def
# 2    Akeel     46  xyz

# %%
pwd
# Out:
# '/content'

# %%
df.to_csv('lpu_without_index.csv', index=False)

# %%
df.head(2)
# Out:
#       name  Marks City
# 0  Pardeep     45  abc
# 1   Sachin     34  def

# %%
df.tail(2)
# Out:
#      name  Marks City
# 1  Sachin     34  def
# 2   Akeel     46  xyz

# %%
df.describe()
# Out:
#            Marks
# count   3.000000
# mean   41.666667
# std     6.658328
# min    34.000000
# 25%    39.500000
# 50%    45.000000
# 75%    45.500000
# max    46.000000

# %%
 #we can import that file is present in pwd
df1= pd.read_csv("lpu_without_index.csv")

# %%
from google.colab import files
uploaded = files.upload()
import io
df1 = pd.read_csv(io.BytesIO(uploaded['lpu_without_index.csv']))
# Out:
#      <input type="file" id="files-3b791106-b8e2-45e0-9d3c-55b674cc87d6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3b791106-b8e2-45e0-9d3c-55b674cc87d6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df1
# Out:
#       name  Marks City
# 0  Pardeep     45  abc
# 1   Sachin     34  def
# 2    Akeel     46  xyz

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
# series is one-dimensional 
ser= pd.Series(np.random.rand(10))
ser
# Out:
# 0    0.617824
# 1    0.752861
# 2    0.717560
# 3    0.154630
# 4    0.302288
# 5    0.843827
# 6    0.347251
# 7    0.731137
# 8    0.736065
# 9    0.756941
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
df2= pd.DataFrame(np.random.rand(334,5), index= np.arange(334))

# %%
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.head()
# Out:
#           0         1         2         3         4
# 0  0.070214  0.887595  0.346364  0.755033  0.324942
# 1  0.777756  0.489765  0.380332  0.930334  0.183172
# 2  0.790414  0.717918  0.215734  0.073345  0.296668
# 3  0.351122  0.120557  0.864029  0.872085  0.611752
# 4  0.768812  0.716978  0.189564  0.523843  0.567736

# %%
df2.tail()
# Out:
#             0         1         2         3         4
# 329  0.381567  0.993057  0.259669  0.589787  0.976477
# 330  0.209148  0.809669  0.992113  0.493223  0.245777
# 331  0.431268  0.306344  0.843900  0.951510  0.781626
# 332  0.602756  0.343334  0.004420  0.939430  0.970702
# 333  0.889282  0.096238  0.570936  0.322215  0.697616

# %%
df2.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4    float64
# dtype: object
